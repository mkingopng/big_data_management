# %%
from pyspark.sql import SparkSession, Row

# %%
# create HDFS directory
# $ hdfs dfs -mkdir -p /user/user

# %%
# move txt files to it
# $ hdfs dfs -put orders.csv

# %%
# start a spark session
spark = SparkSession.builder.master("local").appName("cases").getOrCreate()

# %%
# read the csv file
cases = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/michaelkennethkingston@gmail.com/cases_locations.csv")

# %%
# 
cases.take(5)
# Out:
# Out[9]: [Row(notification_date='2020-03-27', postcode='2011', lhd_2010_code='X720', lhd_2010_name='South Eastern Sydney', lga_code19='17200', lga_name19='Sydney (C)', num='1'),
#  Row(notification_date='2020-03-27', postcode='2035', lhd_2010_code='X720', lhd_2010_name='South Eastern Sydney', lga_code19='16550', lga_name19='Randwick (C)', num='1'),
#  Row(notification_date='2020-03-27', postcode='2011', lhd_2010_code='X720', lhd_2010_name='South Eastern Sydney', lga_code19='17200', lga_name19='Sydney (C)', num='1'),
#  Row(notification_date='2020-03-27', postcode='2122', lhd_2010_code='X760', lhd_2010_name='Northern Sydney', lga_code19='16700', lga_name19='Ryde (C)', num='1'),
#  Row(notification_date='2020-03-27', postcode='2257', lhd_2010_code='X770', lhd_2010_name='Central Coast', lga_code19='11650', lga_name19='Central Coast (C) (NSW)', num='1')]

# %%
# create a view to query
cases.createOrReplaceTempView("cases")

# %%
# query 
results = spark.sql("SELECT lhd_2010_name AS lhd_names, lhd_2010_code AS lhd_code, notification_date AS date, num FROM cases").show()
# should have no headers?
# group by lhd names or lhd_code
# calulate maximum daily increase of confirmed cases
# sort by daily increase desc, date asc, lhd desc
# Out:
# +--------------------+--------+----------+---+
# |           lhd_names|lhd_code|      date|num|
# +--------------------+--------+----------+---+
# |South Eastern Sydney|    X720|2020-03-27|  1|
# |South Eastern Sydney|    X720|2020-03-27|  1|
# |South Eastern Sydney|    X720|2020-03-27|  1|
# |     Northern Sydney|    X760|2020-03-27|  1|
# |       Central Coast|    X770|2020-03-27|  1|
# |        Northern NSW|    X810|2020-03-27|  1|
# |South Eastern Sydney|    X720|2020-03-27|  1|
# |        Murrumbidgee|    X840|2020-03-27|  1|
# |              Sydney|    X700|2020-03-27|  1|
# |South Eastern Sydney|    X720|2020-03-27|  1|
# |     Mid North Coast|    X820|2020-03-27|  1|
# |              Sydney|    X700|2020-03-27|  1|
# |       Central Coast|    X770|2020-03-27|  1|
# |        Southern NSW|    X830|2020-03-27|  1|
# |     Northern Sydney|    X760|2020-03-27|  1|
# |     Northern Sydney|    X760|2020-03-27|  1|
# |         Western NSW|    X850|2020-03-27|  1|
# |      Western Sydney|    X740|2020-03-27|  1|
# |  Hunter New England|    X800|2020-03-27|  1|
# |     Northern Sydney|    X760|2020-03-27|  1|
# +--------------------+--------+----------+---+
# only showing top 20 rows

# %%
# save results in the result-sql folder in hdfs
